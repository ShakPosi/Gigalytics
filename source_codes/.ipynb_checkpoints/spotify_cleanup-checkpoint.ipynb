# %% [markdown]
# # Data Cleansing for Spotify Dataset

# %%
import pandas as pd
df_weeklyTop200 = pd.read_csv('../datasets/spotify_top_200_weekly.csv')
df_track_details = pd.read_csv('../datasets/spotify_track_details.csv')
df_artists = pd.read_csv('../datasets/kaggle_artists.csv')
# Out:
# C:\Users\adebola\.conda\envs\New_Base_Py3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (2,4,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_weeklyTop200.head()
# Out:
#    Position                                Track Name         Artist  Streams  \
# 0         1                         Someone You Loved  Lewis Capaldi  3338234
# 1         2  break up with your girlfriend, i'm bored  Ariana Grande  3041558
# 2         3               Giant (with Rag'n'Bone Man)  Calvin Harris  2846784
# 3         4                                   7 rings  Ariana Grande  2836252
# 4         5                          Don't Call Me Up          Mabel  2783485
#
#                      date region              spotify_id
# 0  2019-03-01--2019-03-08     gb  2TIlqbIneP0ZY1O0EzYLlc
# 1  2019-03-01--2019-03-08     gb  4kV4N9D1iKVxx1KLvtTpjS
# 2  2019-03-01--2019-03-08     gb  5itOtNx0WxtJmi1TQ3RuRd
# 3  2019-03-01--2019-03-08     gb  6ocbgoVGwYJhOv1GgI9NsF
# 4  2019-03-01--2019-03-08     gb  5WHTFyqSii0lmT9R21abT8

# %%
df_weeklyTop200.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20800 entries, 0 to 20799
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Position    20800 non-null  int64
#  1   Track Name  20800 non-null  object
#  2   Artist      20800 non-null  object
#  3   Streams     20800 non-null  int64
#  4   date        20800 non-null  object
#  5   region      20800 non-null  object
#  6   spotify_id  20800 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 1.1+ MB

# %%
#df_weeklyTop200['Start_Date'] = df_weeklyTop200.apply(lambda row: row.date[:10],row.date[10:] axis = 1) 
df_weeklyTop200.describe(include='all')
#df_weeklyTop200.describe()
# Out:
#             Position    Track Name         Artist       Streams  \
# count   20800.000000         20800          20800  2.080000e+04
# unique           NaN          1586            554           NaN
# top              NaN  Lucid Dreams  Billie Eilish           NaN
# freq             NaN           104            870           NaN
# mean      100.500000           NaN            NaN  4.779709e+06
# std        57.735693           NaN            NaN  5.885641e+06
# min         1.000000           NaN            NaN  3.240530e+05
# 25%        50.750000           NaN            NaN  5.254700e+05
# 50%       100.500000           NaN            NaN  4.265072e+06
# 75%       150.250000           NaN            NaN  6.594272e+06
# max       200.000000           NaN            NaN  6.723764e+07
#
#                           date  region              spotify_id
# count                    20800   20800                   20800
# unique                      52       2                    1850
# top     2020-01-10--2020-01-17  global  285pBltuF7vW8TeWk8hdRR
# freq                       400   10400                     104
# mean                       NaN     NaN                     NaN
# std                        NaN     NaN                     NaN
# min                        NaN     NaN                     NaN
# 25%                        NaN     NaN                     NaN
# 50%                        NaN     NaN                     NaN
# 75%                        NaN     NaN                     NaN
# max                        NaN     NaN                     NaN

# %%
df_weeklyTop200['date'][10:]
# Out:
# 10       2019-03-01--2019-03-08
# 11       2019-03-01--2019-03-08
# 12       2019-03-01--2019-03-08
# 13       2019-03-01--2019-03-08
# 14       2019-03-01--2019-03-08
#                   ...
# 20795    2020-02-21--2020-02-28
# 20796    2020-02-21--2020-02-28
# 20797    2020-02-21--2020-02-28
# 20798    2020-02-21--2020-02-28
# 20799    2020-02-21--2020-02-28
# Name: date, Length: 20790, dtype: object

# %%
df_weeklyTop200[['start_date', 'end_date']] = df_weeklyTop200['date'].str.split('--', expand=True)
4fdbb4c-e4b7-47a0-b83b-d91bbfcfa387   Ariana Grande
#
#                                            track_url  track_popularity  \
# 0  https://open.spotify.com/track/2TIlqbIneP0ZY1O...                82
# 1  https://open.spotify.com/track/4kV4N9D1iKVxx1K...                81
# 2  https://open.spotify.com/track/5itOtNx0WxtJmi1...                80
# 3  https://open.spotify.com/track/5itOtNx0WxtJmi1...                80
# 4  https://open.spotify.com/track/6ocbgoVGwYJhOv1...                87
#
#    track_duration_ms  track_is_local                 albumID  \
# 0             182160           False  0NVQ9k3wKmuK6T02lLMl6y
# 1             190440           False  2fYhqwDWXjbpjaIJPEfKFw
# 2             229184           False  4PwXTHenZZx7ebgsnTM65K
# 3             229184           False  4PwXTHenZZx7ebgsnTM65K
# 4             178626           False  2fYhqwDWXjbpjaIJPEfKFw
#
#    album_track_number album_release_date album_type
# 0                   3         2018-11-08     single
# 1                  12         2019-02-08      album
# 2                   1         2019-01-11     single
# 3                   1         2019-01-11     single
# 4                  10         2019-02-08      album

# %%
df_track_details.describe(include='all')
# Out:
#                track_spotifyID        artist_spotifyID  \
# count                     3057                    3057
# unique                    1850                     871
# top     5WnfnSpuNEGXyEt78PBA6d  246dkjvS1zLTtiykXe5h60
# freq                        10                      48
# mean                       NaN                     NaN
# std                        NaN                     NaN
# min                        NaN                     NaN
# 25%                        NaN                     NaN
# 50%                        NaN                     NaN
# 75%                        NaN                     NaN
# max                        NaN                     NaN
#
#                                  artist_mbid  artist_name  \
# count                                   2428         3057
# unique                                   594          869
# top     b1e26560-60e5-4236-bbdb-9aa5a8d5ee19  Post Malone
# freq                                      48           48
# mean                                     NaN          NaN
# std                                      NaN          NaN
# min                                      NaN          NaN
# 25%                                      NaN          NaN
# 50%                                      NaN          NaN
# 75%                                      NaN          NaN
# max                                      NaN          NaN
#
#                                                 track_url  track_popularity  \
# count                                                3057       3057.000000
# unique                                               1850               NaN
# top     https://open.spotify.com/track/5WnfnSpuNEGXyEt...               NaN
# freq                                                   10               NaN
# mean                                                  NaN         65.875368
# std                                                   NaN         18.418683
# min                                                   NaN          0.000000
# 25%                                                   NaN         59.000000
# 50%                                                   NaN         70.000000
# 75%                                                   NaN         78.000000
# max                                                   NaN        100.000000
#
#         track_duration_ms track_is_local                 albumID  \
# count         3057.000000           3057                    3057
# unique                NaN              1                    1222
# top                   NaN          False  3oIFxDIo2fwuk4lwCmFZCx
# freq                  NaN           3057                      37
# mean        205305.352633            NaN                     NaN
# std          46454.953704            NaN                     NaN
# min          30133.000000            NaN                     NaN
# 25%         175755.000000            NaN                     NaN
# 50%         200186.000000            NaN                     NaN
# 75%         224000.000000            NaN                     NaN
# max         667706.000000            NaN                     NaN
#
#         album_track_number album_release_date album_type
# count          3057.000000               3057       3057
# unique                 NaN                464          3
# top                    NaN         2019-09-06      album
# freq                   NaN                 86       1561
# mean              4.037291                NaN        NaN
# std               4.518568                NaN        NaN
# min               1.000000                NaN        NaN
# 25%               1.000000                NaN        NaN
# 50%               1.000000                NaN        NaN
# 75%               6.000000                NaN        NaN
# max              55.000000                NaN        NaN

# %%
df_track_details.isna().any()
# Out:
# track_spotifyID       False
# artist_spotifyID      False
# artist_mbid            True
# artist_name           False
# track_url             False
# track_popularity      False
# track_duration_ms     False
# track_is_local        False
# albumID               False
# album_track_number    False
# album_release_date    False
# album_type            False
# dtype: bool

# %%
df_null_mbid = df_track_details[df_track_details['artist_mbid'].isnull()]
df_null_mbid
#df_track_details[df_track_details['artist_mbid'].notnull()]
# Out:
#              track_spotifyID        artist_spotifyID artist_mbid  \
# 3     5itOtNx0WxtJmi1TQ3RuRd  4f9iBmdUOhQWeP7dcAn1pf         NaN
# 11    2VxeLyX666F8uXCJ0dZF8B  4VIvfOurcf0vuLRxLkGnIG         NaN
# 12    2cytBOLpwFRX7J9URCrFIe  31Ua7zSTJxegjyd49ujbSA         NaN
# 13    2cytBOLpwFRX7J9URCrFIe  7b79bQFziJFedJb75k6hFt         NaN
# 30    1fp2uoWXPca3mIdxRHIgQm  1Gm0kKaDx4GH6pQF88rjSK         NaN
# ...                      ...                     ...         ...
# 3024  0rETge1bMavnW9leLCnpwd  2PJEagPIxaBugeMjIyKVXF         NaN
# 3025  0rETge1bMavnW9leLCnpwd  2yPprAQlrIQWu60g09B9MZ         NaN
# 3026  0rETge1bMavnW9leLCnpwd  1VeNLxolTVovUG1ROeumVp         NaN
# 3030  3H3r2nKWa3Yk5gt8xgmsEt  6L1XC7NrmgWRlwAeLJvVtA         NaN
# 3052  4dZTZbmJBCCofAExHwefda  5bgfj5zUoWpyeVatGDjn6H         NaN
#
#          artist_name                                          track_url  \
# 3     Rag'n'Bone Man  https://open.spotify.com/track/5itOtNx0WxtJmi1...
# 11    Bradley Cooper  https://open.spotify.com/track/2VxeLyX666F8uXC...
# 12               NSG  https://open.spotify.com/track/2cytBOLpwFRX7J9...
# 13        Tion Wayne  https://open.spotify.com/track/2cytBOLpwFRX7J9...
# 30             Cadet  https://open.spotify.com/track/1fp2uoWXPca3mId...
# ...              ...                                                ...
# 3024           Aitch  https://open.spotify.com/track/0rETge1bMavnW9l...
# 3025          Swarmz  https://open.spotify.com/track/0rETge1bMavnW9l...
# 3026           Sav'o  https://open.spotify.com/track/0rETge1bMavnW9l...
# 3030     Sam Fischer  https://open.spotify.com/track/3H3r2nKWa3Yk5gt...
# 3052          K CAMP  https://open.spotify.com/track/4dZTZbmJBCCofAE...
#
#       track_popularity  track_duration_ms  track_is_local  \
# 3                   80             229184           False
# 11                  86             215733           False
# 12                  69             240081           False
# 13                  69             240081           False
# 30                  65             192571           False
# ...                ...                ...             ...
# 3024                59             252906           False
# 3025                59             252906           False
# 3026                59             252906           False
# 3030                80             194853           False
# 3052                81             170946           False
#
#                      albumID  album_track_number album_release_date album_type
# 3     4PwXTHenZZx7ebgsnTM65K                   1         2019-01-11     single
# 11    4sLtOBOzn4s3GDUv3c5oJD                  12         2018-10-05      album
# 12    35MvbFXqp1ESDkKNqYfOIM                   1         2018-11-30     single
# 13    35MvbFXqp1ESDkKNqYfOIM                   1         2018-11-30     single
# 30    4wOuGy0YTmOHjHIUo6drO8                   1         2018-09-14     single
# ...                      ...                 ...                ...        ...
# 3024  4NY1IySwIffLWbyYd7Shg0                   1         2019-04-11     single
# 3025  4NY1IySwIffLWbyYd7Shg0                   1         2019-04-11     single
# 3026  4NY1IySwIffLWbyYd7Shg0                   1         2019-04-11     single
# 3030  5waiE6DS2ntWF3Q0yekJUm                   1         2019-12-13     single
# 3052  6Z8fenVdNwyQZ9iBFkNyKZ                  15         2019-06-21      album
#
# [629 rows x 12 columns]
